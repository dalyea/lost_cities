# %%
# Lost Cities V1E
# Starting with V1C
# Creating separate main file and capturing all parameters together
# Still using 43 features

# %%
# import V1E_main as main
from V1E_main import *

# %%
# dir(main)

# %%
# ALL PARAMETERS

# See grid search
# File version
# fv='V1E_2'
# file_name='all_rewards.'+fv+'.csv'

nn_layer_1=96
nn_layer_2=32
nn_layer_2_dropout=0.20
learning_rate=0.001
replay_size=18000
num_episodes = 50_000
batch_size = 64
batch_cnt = 3
train_every = 5
step_booster = 5.0
episode_booster = 0.10 # 0.5 for 1, 1.0 for 2, 0.0 for 3
epsilon = 0.35
epsilon_min = 0.030 # was 0.35 for .2.
epsilon_decay = 0.999999

# Fixed parameters (not in grid)
fixed_params = {
    'epsilon': 0.35,
    'epsilon_min': 0.030,
    'epsilon_decay': 0.999999
}

# Simply comment out any functions not to be included
step_functions=[
'lover_val_avail',
'too_few_pts',
'blocked_7',
'exp_small_deck',
'exp_was_live',
'good_exp',
'bad_X',
'bad_bigger_val',
'good_low_val',
'draw_to_tgt',
# 'had_X',
'next_value',
# 'bad_center',
# 'smart_opp_center'
]

# %%
# config_dict = {
#     "nn_layer_1": nn_layer_1,
#     "nn_layer_2": nn_layer_2,
#     "nn_layer_2_dropout": nn_layer_2_dropout,
#     "learning_rate": learning_rate,
#     "replay_size": replay_size,
#     "num_episodes": num_episodes,
#     "batch_size": batch_size,
#     "batch_cnt": batch_cnt,
#     "train_every": train_every,
#     "step_booster": step_booster,
#     "episode_booster": episode_booster,
#     "epsilon": epsilon,
#     "epsilon_min": epsilon_min,
#     "epsilon_decay": epsilon_decay
# }

# save_config_txt(fv, config_dict, step_functions)

# %%
# Modified Training Loop with Action + Draw Selection from Policy
def train_model(fv, nn_layer_1, nn_layer_2_dropout,
                learning_rate, replay_size, step_booster, episode_booster,
                step_functions, file_name):

    global epsilon, epsilon_min, epsilon_decay
    global batch_size, train_every, batch_cnt

    global all_rewards
    global mean_rewards
    all_rewards = []
    mean_rewards = []

    env = LostCitiesEnv()
    num_card_actions = card_cnt
    num_draw_choices = color_cnt+1
    model = ActorCritic(state_size=state_size, action_size=num_card_actions, draw_size=num_draw_choices, 
                             nn_layer_1=nn_layer_1, nn_layer_2=nn_layer_2, nn_layer_2_dropout=nn_layer_2_dropout)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    replay_buffer = deque(maxlen=replay_size)
    rule_counter = defaultdict(int)
    
    for episode in range(1, num_episodes + 1):
        state = env.reset()
        done = False
        mean_reward = 0.0
        play_cnt=0
        plays_p1 = []
        plays_p2 = []
    
        while not done:
            play_cnt+=1
            features_np = extract_features(state)
            features = torch.tensor(features_np, dtype=torch.float32)
    
            # Forward pass through the model
            card_logits, draw_logits, value = model(features)
    
            # Get legal actions and legal draws
            # actions, draws = env.get_legal_actions(state['current_player'])
            actions, draws = env.get_legal_actions(state['current_player'])
            legal_action_indices = list(range(len(actions)))
    
            valid_draws = [d for d in draws if d == 'deck' or (d in env.center_piles and env.center_piles[d])]
            if not valid_draws:
                print("No valid draws—forcing episode end.")
                done = True
                break
    
            # legal_draw_indices = list(range(len(valid_draws)))  # typically ['deck', 'R', 'B', 'G']
    
            # Stop this game is no legal actions - though this is of course not true, but...
            # Print discard and draw for plays 1001 to 1020
            if 10001 <= play_cnt <= 10020:
                print(f"Legal actions: {actions}")
                print(f"Action indices: {[i for i in range(len(actions))]}")
                # Not valid at this point
                # print(f"Play {play_cnt}: Discard action = {chosen_action}, Draw choice = {chosen_draw}")
            if play_cnt>=10020:
                print(play_cnt, actions, draws, valid_draws)
                print(f"\n--- STUCK STATE at play {play_cnt} ---")
                print(f"Deck size: {state['deck_size']}")
                print(f"Player hand: {state['hands'][state['current_player']]}")
                print(f"Expeditions:")
                for color in env.expeditions[state['current_player']]:
                    print(f"  {color}: {env.expeditions[state['current_player']][color]}")
                print(f"Center piles:")
                for color in env.center_piles:
                    print(f"  {color}: {env.center_piles[color]}")
                print(f"Available actions: {actions}")
                print(f"Available draws: {draws}")
                print(f"----------------------\n")
                raise SystemExit(f"STOP")
            
            if not actions:
                print(f"No legal actions for player {state['current_player']}. Ending episode early.")
                done = True
                break
    
            # Sample card action with epsilon-greedy
            if random.random() < epsilon:
                # Random action
                card_idx = random.randint(0, len(actions) - 1)
            else:
                # Model-based action
                card_probs = torch.softmax(card_logits[:len(actions)], dim=0)
                card_dist = torch.distributions.Categorical(card_probs)
                card_idx = card_dist.sample().item()
            
            chosen_action = actions[card_idx]
    
            # Filter valid draws based on chosen_action (if it's a center discard)
            discard_color = None
            if chosen_action[0] == 'center':
                discard_color = chosen_action[1][0]
            
            filtered_draws = [
                d for d in valid_draws if d != discard_color
            ]
            if not filtered_draws:
                # Failsafe: fallback to deck
                filtered_draws = ['deck']
    
            valid_draws=filtered_draws
    
            # Sample draw choice (FIXED)
            if random.random() < epsilon:
                chosen_draw = random.choice(valid_draws)
            else:
                # Correct mapping: get logits only for valid draws
                draw_indices_in_logits = [draw_to_index[d] for d in valid_draws]
                draw_logits_filtered = draw_logits[draw_indices_in_logits]
                draw_probs = torch.softmax(draw_logits_filtered, dim=0)
                draw_dist = torch.distributions.Categorical(draw_probs)
                draw_idx = draw_dist.sample().item()
                chosen_draw = valid_draws[draw_idx]
    
            # Compute shaped intermediate reward
            step_reward = compute_step_reward(state, chosen_action, chosen_draw, env, step_functions, rule_counter)
    
            # Map draw_choice to its index for policy update
            chosen_draw_idx = draw_to_index[chosen_draw]
    
            # Save the current player before doing env.step
            current_player=state['current_player']
            
            # Take action and draw based on policies
            next_state, reward, done = env.step(chosen_action, chosen_draw)
    
            # Combine shaped reward + final score (if any)
            # total_reward = reward + booster * step_reward
            total_reward = step_booster * step_reward
    
            # Store full experience (must include both action idx and draw idx!)
            # replay_buffer.append((features_np, card_idx, chosen_draw_idx, total_reward))
            # Now, do it all at end of game
            if current_player=='P1':
                plays_p1.append((features_np, card_idx, chosen_draw_idx, step_reward))
            else:
                plays_p2.append((features_np, card_idx, chosen_draw_idx, step_reward))
                
            # Advance state
            state = next_state
            mean_reward += total_reward
    
            # Annealing
            epsilon = max(epsilon_min, epsilon * epsilon_decay)
    
            ddebug = random.random()<1e-6
            if done:
                reward_p1 = env.compute_score('P1')
                reward_p2 = env.compute_score('P2')
                p1cnt=0
                for (features_np, card_idx, draw_idx, step_reward) in plays_p1:
                    total_reward = episode_booster * reward_p1 + step_reward
                    replay_buffer.append((features_np, card_idx, draw_idx, total_reward))
                    if ddebug:
                        p1cnt+=1
                        print(f"P1 {p1cnt} - {episode_booster} * {reward_p1} + {step_reward} = {total_reward}")
                for (features_np, card_idx, draw_idx, step_reward) in plays_p2:
                    total_reward = episode_booster * reward_p2 + step_reward
                    replay_buffer.append((features_np, card_idx, draw_idx, total_reward))
    
        # Final mean reward is the average over plays - approximate over P1 and P2
        mean_reward=1.0*mean_reward/play_cnt
        
        if play_cnt>200:
            print(f"Plays: {play_cnt} in episode {episode}")
    
        # Train
        if episode % train_every == 0 and len(replay_buffer) >= batch_size:
            for _ in range(batch_cnt):
                minibatch = random.sample(replay_buffer, batch_size)
        
                # Unpack minibatch into separate lists
                states_b, actions_b, draws_b, rewards_b = zip(*minibatch)
    
                # Convert lists to tensors
                states_np = np.array(states_b)  # Convert list of arrays → single array
                states_t = torch.tensor(states_np, dtype=torch.float32)
        
                # Convert to tensors in batch
                # states_t = torch.tensor(states_b, dtype=torch.float32)  # Shape: [batch_size, state_size]
                actions_t = torch.tensor(actions_b, dtype=torch.long)   # Shape: [batch_size]
                draws_t = torch.tensor(draws_b, dtype=torch.long)       # Shape: [batch_size]
                rewards_t = torch.tensor(rewards_b, dtype=torch.float32)  # Shape: [batch_size]
        
                # Forward pass in batch
                card_logits_b, draw_logits_b, values_b = model(states_t)  # Each output shape: [batch_size, num_actions/draws]
        
                # Compute log probs for card actions
                card_probs_b = torch.softmax(card_logits_b, dim=1)
                log_card_probs_b = torch.log(card_probs_b + 1e-8)
                selected_log_card_probs = log_card_probs_b[range(batch_size), actions_t]
        
                # Compute log probs for draws
                draw_probs_b = torch.softmax(draw_logits_b, dim=1)
                log_draw_probs_b = torch.log(draw_probs_b + 1e-8)
                selected_log_draw_probs = log_draw_probs_b[range(batch_size), draws_t]
        
                # Compute advantage
                advantages = rewards_t - values_b.squeeze(1)  # Shape: [batch_size]
        
                # Losses
                critic_loss = advantages.pow(2).mean()
                actor_loss_card = -(selected_log_card_probs * advantages).mean()
                actor_loss_draw = -(selected_log_draw_probs * advantages).mean()
        
                total_loss = critic_loss + actor_loss_card + actor_loss_draw
        
                optimizer.zero_grad()
                total_loss.backward()
                optimizer.step()
    
        all_rewards.append(reward_p1)
        all_rewards.append(reward_p2)    
        mean_rewards.append(mean_reward)
    
        if episode % 1000 == 0:
            print("\n=== Step Rule Firing Counts ===")
            for rule, count in sorted(rule_counter.items(), key=lambda x: -x[1]):
                print(f"{rule:<30}: {count}")
            pd.Series(all_rewards).to_csv(file_name, index=False, header=False)
        
        if episode % 200 == 0:
            avg_score = np.mean(all_rewards[-2000:]) if len(all_rewards) >= 2000 else np.mean(all_rewards)
            print(f"Episode {episode}, Average Reward Last {min(len(all_rewards), 1000)}: {avg_score:.2f}, eps={epsilon:.4f}")

# %%
from itertools import product
import datetime
import os

running=1

# All grid search options
# "nn_layer_2": [32, 16],
grid = {
    "nn_layer_1": [64], # No 96
    "nn_layer_2_dropout": [0.1], # No 0.2
    "learning_rate": [0.001, 0.002],
    "replay_size": [10000, 20000],
    "step_booster": [2.5, 5.0],
    "episode_booster": [0.1, 0.5],
    "step_functions": [
        ['good_exp', 'draw_to_tgt'],
        ['good_exp', 'draw_to_tgt', 'too_few_pts'],
        ['good_exp', 'draw_to_tgt', 'too_few_pts', 'good_low_val'],
        ['good_exp', 'draw_to_tgt', 'too_few_pts', 'good_low_val','next_value']
    ]
}

# draw_to_tgt                   : 315239
# good_exp_1                    : 239211 (good_exp)
# too_few_pts                   : 178103
# good_exp                      : 151163
# good_low_val                  : 122132
# blocked_7                     : 119373
# next_value                    : 81343

# Create Cartesian product of all combinations
keys, values = zip(*grid.items())
combinations = list(product(*values))

print(f"Total runs: {len(combinations)}")

# Main loop
for idx, combo in enumerate(combinations):
    params = dict(zip(keys, combo))
    fv = f"grid_{idx:02d}_{datetime.datetime.now().strftime('%H%M%S')}"
    file_name = f"all_rewards.{running}.{fv}.csv"

    # Add file_name to params so it can be passed to train_model
    params['file_name'] = file_name

    # Merge fixed params
    # params.update(fixed_params)
    
    # Save config file
    save_config_txt(running, fv, params, params['step_functions'])

    # --- Insert call to train() function or run_ipynb main code here ---
    # Example:
    train_model(fv, **params)

    # Optional: log progress
    print(f"Finished run {idx+1}/{len(combinations)} → {file_name}")
# Out:
# Total runs: 64
# Configuration saved to config_1_grid_00_221419.txt
# Episode 200, Average Reward Last 400: -5.04, eps=0.3482
# Episode 400, Average Reward Last 800: -5.40, eps=0.3463
# Episode 600, Average Reward Last 1000: -5.21, eps=0.3444
# Episode 800, Average Reward Last 1000: -5.00, eps=0.3424
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 5681
# good_exp_1                    : 4523
# good_exp                      : 2849
# Episode 1000, Average Reward Last 1000: -4.97, eps=0.3405
# Episode 1200, Average Reward Last 1000: -4.86, eps=0.3386
# Episode 1400, Average Reward Last 1000: -4.70, eps=0.3367
# Episode 1600, Average Reward Last 1000: -4.66, eps=0.3348
# Episode 1800, Average Reward Last 1000: -4.73, eps=0.3329
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 11625
# good_exp_1                    : 9097
# good_exp                      : 5793
# Episode 2000, Average Reward Last 1000: -4.69, eps=0.3311
# Episode 2200, Average Reward Last 1000: -4.76, eps=0.3293
# Episode 2400, Average Reward Last 1000: -4.57, eps=0.3274
# Episode 2600, Average Reward Last 1000: -4.64, eps=0.3256
# Episode 2800, Average Reward Last 1000: -4.54, eps=0.3238
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 17516
# good_exp_1                    : 13697
# good_exp                      : 8641
# Episode 3000, Average Reward Last 1000: -4.46, eps=0.3221
# Episode 3200, Average Reward Last 1000: -4.41, eps=0.3203
# Episode 3400, Average Reward Last 1000: -4.41, eps=0.3185
# Episode 3600, Average Reward Last 1000: -4.22, eps=0.3168
# Episode 3800, Average Reward Last 1000: -4.07, eps=0.3151
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 23095
# good_exp_1                    : 18357
# good_exp                      : 11555
# Episode 4000, Average Reward Last 1000: -4.14, eps=0.3134
# Episode 4200, Average Reward Last 1000: -4.07, eps=0.3118
# Episode 4400, Average Reward Last 1000: -4.04, eps=0.3101
# Episode 4600, Average Reward Last 1000: -4.01, eps=0.3084
# Episode 4800, Average Reward Last 1000: -4.11, eps=0.3068
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 28407
# good_exp_1                    : 23150
# good_exp                      : 14552
# Episode 5000, Average Reward Last 1000: -3.91, eps=0.3051
# Episode 5200, Average Reward Last 1000: -3.80, eps=0.3034
# Episode 5400, Average Reward Last 1000: -3.82, eps=0.3018
# Episode 5600, Average Reward Last 1000: -3.83, eps=0.3001
# Episode 5800, Average Reward Last 1000: -3.72, eps=0.2985
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 33860
# good_exp_1                    : 27848
# good_exp                      : 17443
# Episode 6000, Average Reward Last 1000: -3.79, eps=0.2969
# Episode 6200, Average Reward Last 1000: -3.89, eps=0.2952
# Episode 6400, Average Reward Last 1000: -3.86, eps=0.2936
# Episode 6600, Average Reward Last 1000: -3.78, eps=0.2920
# Episode 6800, Average Reward Last 1000: -3.85, eps=0.2905
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 39242
# good_exp_1                    : 32565
# good_exp                      : 20361
# Episode 7000, Average Reward Last 1000: -3.77, eps=0.2889
# Episode 7200, Average Reward Last 1000: -3.66, eps=0.2874
# Episode 7400, Average Reward Last 1000: -3.47, eps=0.2859
# Episode 7600, Average Reward Last 1000: -3.63, eps=0.2844
# Episode 7800, Average Reward Last 1000: -3.47, eps=0.2828
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 44497
# good_exp_1                    : 37530
# good_exp                      : 23499
# Episode 8000, Average Reward Last 1000: -3.50, eps=0.2813
# Episode 8200, Average Reward Last 1000: -3.49, eps=0.2798
# Episode 8400, Average Reward Last 1000: -3.65, eps=0.2784
# Episode 8600, Average Reward Last 1000: -3.65, eps=0.2769
# Episode 8800, Average Reward Last 1000: -3.71, eps=0.2755
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 49425
# good_exp_1                    : 42318
# good_exp                      : 26489
# Episode 9000, Average Reward Last 1000: -3.68, eps=0.2740
# Episode 9200, Average Reward Last 1000: -3.52, eps=0.2725
# Episode 9400, Average Reward Last 1000: -3.38, eps=0.2711
# Episode 9600, Average Reward Last 1000: -3.19, eps=0.2697
# Episode 9800, Average Reward Last 1000: -3.24, eps=0.2683
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 54114
# good_exp_1                    : 47271
# good_exp                      : 29534
# Episode 10000, Average Reward Last 1000: -3.10, eps=0.2669
# Episode 10200, Average Reward Last 1000: -3.21, eps=0.2656
# Episode 10400, Average Reward Last 1000: -3.20, eps=0.2642
# Episode 10600, Average Reward Last 1000: -3.02, eps=0.2629
# Episode 10800, Average Reward Last 1000: -2.88, eps=0.2615
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 58846
# good_exp_1                    : 52313
# good_exp                      : 32690
# Episode 11000, Average Reward Last 1000: -2.82, eps=0.2602
# Episode 11200, Average Reward Last 1000: -2.70, eps=0.2588
# Episode 11400, Average Reward Last 1000: -2.48, eps=0.2575
# Episode 11600, Average Reward Last 1000: -2.73, eps=0.2562
# Episode 11800, Average Reward Last 1000: -2.66, eps=0.2549
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 63578
# good_exp_1                    : 57294
# good_exp                      : 35789
# Episode 12000, Average Reward Last 1000: -2.88, eps=0.2535
# Episode 12200, Average Reward Last 1000: -3.09, eps=0.2523
# Episode 12400, Average Reward Last 1000: -3.30, eps=0.2509
# Episode 12600, Average Reward Last 1000: -3.24, eps=0.2497
# Episode 12800, Average Reward Last 1000: -3.40, eps=0.2484
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 68427
# good_exp_1                    : 62220
# good_exp                      : 38915
# Episode 13000, Average Reward Last 1000: -3.39, eps=0.2471
# Episode 13200, Average Reward Last 1000: -3.21, eps=0.2458
# Episode 13400, Average Reward Last 1000: -3.27, eps=0.2446
# Episode 13600, Average Reward Last 1000: -3.20, eps=0.2433
# Episode 13800, Average Reward Last 1000: -3.19, eps=0.2421
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 73104
# good_exp_1                    : 67220
# good_exp                      : 42070
# Episode 14000, Average Reward Last 1000: -3.12, eps=0.2408
# Episode 14200, Average Reward Last 1000: -3.01, eps=0.2395
# Episode 14400, Average Reward Last 1000: -3.15, eps=0.2383
# Episode 14600, Average Reward Last 1000: -3.23, eps=0.2371
# Episode 14800, Average Reward Last 1000: -3.05, eps=0.2359
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 77750
# good_exp_1                    : 72100
# good_exp                      : 45180
# Episode 15000, Average Reward Last 1000: -3.12, eps=0.2347
# Episode 15200, Average Reward Last 1000: -3.43, eps=0.2333
# Episode 15400, Average Reward Last 1000: -3.33, eps=0.2320
# Episode 15600, Average Reward Last 1000: -3.48, eps=0.2307
# Episode 15800, Average Reward Last 1000: -3.70, eps=0.2295
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 83093
# good_exp_1                    : 76966
# good_exp                      : 48233
# Episode 16000, Average Reward Last 1000: -3.68, eps=0.2283
# Episode 16200, Average Reward Last 1000: -3.61, eps=0.2271
# Episode 16400, Average Reward Last 1000: -3.75, eps=0.2259
# Episode 16600, Average Reward Last 1000: -3.63, eps=0.2247
# Episode 16800, Average Reward Last 1000: -3.70, eps=0.2235
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 88159
# good_exp_1                    : 81805
# good_exp                      : 51211
# Episode 17000, Average Reward Last 1000: -3.86, eps=0.2223
# Episode 17200, Average Reward Last 1000: -3.88, eps=0.2212
# Episode 17400, Average Reward Last 1000: -3.74, eps=0.2200
# Episode 17600, Average Reward Last 1000: -3.80, eps=0.2188
# Episode 17800, Average Reward Last 1000: -4.00, eps=0.2177
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 93402
# good_exp_1                    : 86677
# good_exp                      : 54238
# Episode 18000, Average Reward Last 1000: -3.91, eps=0.2165
# Episode 18200, Average Reward Last 1000: -4.05, eps=0.2154
# Episode 18400, Average Reward Last 1000: -4.13, eps=0.2143
# Episode 18600, Average Reward Last 1000: -4.07, eps=0.2131
# Episode 18800, Average Reward Last 1000: -3.93, eps=0.2120
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 98553
# good_exp_1                    : 91533
# good_exp                      : 57266
# Episode 19000, Average Reward Last 1000: -3.90, eps=0.2109
# Episode 19200, Average Reward Last 1000: -3.71, eps=0.2097
# Episode 19400, Average Reward Last 1000: -3.70, eps=0.2086
# Episode 19600, Average Reward Last 1000: -3.72, eps=0.2075
# Episode 19800, Average Reward Last 1000: -3.65, eps=0.2063
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 103817
# good_exp_1                    : 96309
# good_exp                      : 60224
# Episode 20000, Average Reward Last 1000: -3.60, eps=0.2052
# Episode 20200, Average Reward Last 1000: -3.60, eps=0.2040
# Episode 20400, Average Reward Last 1000: -3.45, eps=0.2028
# Episode 20600, Average Reward Last 1000: -3.25, eps=0.2017
# Episode 20800, Average Reward Last 1000: -3.17, eps=0.2005
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 109717
# good_exp_1                    : 101336
# good_exp                      : 63422
# Episode 21000, Average Reward Last 1000: -2.94, eps=0.1994
# Episode 21200, Average Reward Last 1000: -2.94, eps=0.1983
# Episode 21400, Average Reward Last 1000: -2.95, eps=0.1971
# Episode 21600, Average Reward Last 1000: -2.88, eps=0.1960
# Episode 21800, Average Reward Last 1000: -2.81, eps=0.1949
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 115528
# good_exp_1                    : 106325
# good_exp                      : 66584
# Episode 22000, Average Reward Last 1000: -3.06, eps=0.1937
# Episode 22200, Average Reward Last 1000: -3.15, eps=0.1923
# Episode 22400, Average Reward Last 1000: -3.24, eps=0.1910
# Episode 22600, Average Reward Last 1000: -3.55, eps=0.1898
# Episode 22800, Average Reward Last 1000: -3.80, eps=0.1885
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 122692
# good_exp_1                    : 111128
# good_exp                      : 69630
# Episode 23000, Average Reward Last 1000: -3.65, eps=0.1873
# Episode 23200, Average Reward Last 1000: -3.62, eps=0.1860
# Episode 23400, Average Reward Last 1000: -3.72, eps=0.1848
# Episode 23600, Average Reward Last 1000: -3.75, eps=0.1836
# Episode 23800, Average Reward Last 1000: -3.66, eps=0.1824
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 129533
# good_exp_1                    : 115954
# good_exp                      : 72730
# Episode 24000, Average Reward Last 1000: -3.66, eps=0.1813
# Episode 24200, Average Reward Last 1000: -3.66, eps=0.1802
# Episode 24400, Average Reward Last 1000: -3.62, eps=0.1791
# Episode 24600, Average Reward Last 1000: -3.53, eps=0.1780
# Episode 24800, Average Reward Last 1000: -3.47, eps=0.1770
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 135895
# good_exp_1                    : 120933
# good_exp                      : 75956
# Episode 25000, Average Reward Last 1000: -3.59, eps=0.1759
# Episode 25200, Average Reward Last 1000: -3.52, eps=0.1748
# Episode 25400, Average Reward Last 1000: -3.32, eps=0.1738
# Episode 25600, Average Reward Last 1000: -3.17, eps=0.1727
# Episode 25800, Average Reward Last 1000: -3.21, eps=0.1717
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 142049
# good_exp_1                    : 125891
# good_exp                      : 79087
# Episode 26000, Average Reward Last 1000: -3.27, eps=0.1707
# Episode 26200, Average Reward Last 1000: -2.96, eps=0.1697
# Episode 26400, Average Reward Last 1000: -2.74, eps=0.1688
# Episode 26600, Average Reward Last 1000: -2.39, eps=0.1680
# Episode 26800, Average Reward Last 1000: -1.85, eps=0.1672
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 146595
# good_exp_1                    : 131123
# good_exp                      : 82354
# Episode 27000, Average Reward Last 1000: -1.69, eps=0.1662
# Episode 27200, Average Reward Last 1000: -1.88, eps=0.1653
# Episode 27400, Average Reward Last 1000: -2.24, eps=0.1644
# Episode 27600, Average Reward Last 1000: -2.62, eps=0.1634
# Episode 27800, Average Reward Last 1000: -3.17, eps=0.1625
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 152105
# good_exp_1                    : 136120
# good_exp                      : 85493
# Episode 28000, Average Reward Last 1000: -3.36, eps=0.1616
# Episode 28200, Average Reward Last 1000: -3.52, eps=0.1606
# Episode 28400, Average Reward Last 1000: -3.52, eps=0.1597
# Episode 28600, Average Reward Last 1000: -3.62, eps=0.1588
# Episode 28800, Average Reward Last 1000: -3.36, eps=0.1580
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 157386
# good_exp_1                    : 141134
# good_exp                      : 88626
# Episode 29000, Average Reward Last 1000: -3.20, eps=0.1571
# Episode 29200, Average Reward Last 1000: -3.02, eps=0.1563
# Episode 29400, Average Reward Last 1000: -2.86, eps=0.1555
# Episode 29600, Average Reward Last 1000: -2.81, eps=0.1547
# Episode 29800, Average Reward Last 1000: -3.00, eps=0.1539
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 162186
# good_exp_1                    : 146129
# good_exp                      : 91743
# Episode 30000, Average Reward Last 1000: -3.09, eps=0.1530
# Episode 30200, Average Reward Last 1000: -2.86, eps=0.1522
# Episode 30400, Average Reward Last 1000: -2.87, eps=0.1514
# Episode 30600, Average Reward Last 1000: -2.94, eps=0.1507
# Episode 30800, Average Reward Last 1000: -2.83, eps=0.1499
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 166632
# good_exp_1                    : 151214
# good_exp                      : 94914
# Episode 31000, Average Reward Last 1000: -2.76, eps=0.1492
# Episode 31200, Average Reward Last 1000: -3.16, eps=0.1484
# Episode 31400, Average Reward Last 1000: -3.23, eps=0.1477
# Episode 31600, Average Reward Last 1000: -3.16, eps=0.1468
# Episode 31800, Average Reward Last 1000: -3.51, eps=0.1459
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 172332
# good_exp_1                    : 156039
# good_exp                      : 97900
# Episode 32000, Average Reward Last 1000: -3.74, eps=0.1450
# Episode 32200, Average Reward Last 1000: -3.83, eps=0.1441
# Episode 32400, Average Reward Last 1000: -4.01, eps=0.1432
# Episode 32600, Average Reward Last 1000: -4.23, eps=0.1423
# Episode 32800, Average Reward Last 1000: -4.30, eps=0.1413
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 179306
# good_exp_1                    : 160789
# good_exp                      : 100909
# Episode 33000, Average Reward Last 1000: -4.18, eps=0.1404
# Episode 33200, Average Reward Last 1000: -4.16, eps=0.1396
# Episode 33400, Average Reward Last 1000: -4.01, eps=0.1387
# Episode 33600, Average Reward Last 1000: -3.84, eps=0.1380
# Episode 33800, Average Reward Last 1000: -3.58, eps=0.1373
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 184751
# good_exp_1                    : 165703
# good_exp                      : 103889
# Episode 34000, Average Reward Last 1000: -3.50, eps=0.1366
# Episode 34200, Average Reward Last 1000: -3.18, eps=0.1359
# Episode 34400, Average Reward Last 1000: -3.19, eps=0.1352
# Episode 34600, Average Reward Last 1000: -3.08, eps=0.1345
# Episode 34800, Average Reward Last 1000: -2.84, eps=0.1337
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 189886
# good_exp_1                    : 170767
# good_exp                      : 107050
# Episode 35000, Average Reward Last 1000: -2.65, eps=0.1328
# Episode 35200, Average Reward Last 1000: -2.78, eps=0.1321
# Episode 35400, Average Reward Last 1000: -2.62, eps=0.1313
# Episode 35600, Average Reward Last 1000: -2.56, eps=0.1305
# Episode 35800, Average Reward Last 1000: -2.58, eps=0.1298
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 195419
# good_exp_1                    : 175951
# good_exp                      : 110342
# Episode 36000, Average Reward Last 1000: -2.61, eps=0.1291
# Episode 36200, Average Reward Last 1000: -2.86, eps=0.1283
# Episode 36400, Average Reward Last 1000: -3.24, eps=0.1274
# Episode 36600, Average Reward Last 1000: -3.37, eps=0.1266
# Episode 36800, Average Reward Last 1000: -3.46, eps=0.1258
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 202089
# good_exp_1                    : 180959
# good_exp                      : 113523
# Episode 37000, Average Reward Last 1000: -3.41, eps=0.1251
# Episode 37200, Average Reward Last 1000: -2.90, eps=0.1244
# Episode 37400, Average Reward Last 1000: -2.38, eps=0.1236
# Episode 37600, Average Reward Last 1000: -1.97, eps=0.1227
# Episode 37800, Average Reward Last 1000: -1.73, eps=0.1220
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 207800
# good_exp_1                    : 186211
# good_exp                      : 116847
# Episode 38000, Average Reward Last 1000: -1.61, eps=0.1213
# Episode 38200, Average Reward Last 1000: -1.53, eps=0.1205
# Episode 38400, Average Reward Last 1000: -1.55, eps=0.1199
# Episode 38600, Average Reward Last 1000: -1.64, eps=0.1193
# Episode 38800, Average Reward Last 1000: -1.52, eps=0.1186
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 212435
# good_exp_1                    : 191613
# good_exp                      : 120265
# Episode 39000, Average Reward Last 1000: -1.19, eps=0.1180
# Episode 39200, Average Reward Last 1000: -1.07, eps=0.1173
# Episode 39400, Average Reward Last 1000: -0.76, eps=0.1167
# Episode 39600, Average Reward Last 1000: -0.55, eps=0.1161
# Episode 39800, Average Reward Last 1000: -0.91, eps=0.1154
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 217982
# good_exp_1                    : 196903
# good_exp                      : 123578
# Episode 40000, Average Reward Last 1000: -1.71, eps=0.1145
# Episode 40200, Average Reward Last 1000: -2.10, eps=0.1138
# Episode 40400, Average Reward Last 1000: -2.82, eps=0.1131
# Episode 40600, Average Reward Last 1000: -3.49, eps=0.1122
# Episode 40800, Average Reward Last 1000: -3.80, eps=0.1114
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 225501
# good_exp_1                    : 201632
# good_exp                      : 126575
# Episode 41000, Average Reward Last 1000: -3.93, eps=0.1106
# Episode 41200, Average Reward Last 1000: -4.19, eps=0.1098
# Episode 41400, Average Reward Last 1000: -4.31, eps=0.1089
# Episode 41600, Average Reward Last 1000: -3.96, eps=0.1077
# Episode 41800, Average Reward Last 1000: -3.35, eps=0.1066
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 236418
# good_exp_1                    : 206280
# good_exp                      : 129604
# Episode 42000, Average Reward Last 1000: -2.91, eps=0.1055
# Episode 42200, Average Reward Last 1000: -2.75, eps=0.1046
# Episode 42400, Average Reward Last 1000: -2.46, eps=0.1039
# Episode 42600, Average Reward Last 1000: -2.48, eps=0.1032
# Episode 42800, Average Reward Last 1000: -2.88, eps=0.1025
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 244187
# good_exp_1                    : 211246
# good_exp                      : 132758
# Episode 43000, Average Reward Last 1000: -3.11, eps=0.1018
# Episode 43200, Average Reward Last 1000: -3.01, eps=0.1006
# Episode 43400, Average Reward Last 1000: -2.91, eps=0.0995
# Episode 43600, Average Reward Last 1000: -2.90, eps=0.0987
# Episode 43800, Average Reward Last 1000: -2.97, eps=0.0980
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 254384
# good_exp_1                    : 216164
# good_exp                      : 135990
# Episode 44000, Average Reward Last 1000: -2.87, eps=0.0974
# Episode 44200, Average Reward Last 1000: -3.11, eps=0.0967
# Episode 44400, Average Reward Last 1000: -3.51, eps=0.0959
# Episode 44600, Average Reward Last 1000: -3.98, eps=0.0949
# Episode 44800, Average Reward Last 1000: -4.31, eps=0.0940
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 265708
# good_exp_1                    : 220604
# good_exp                      : 138863
# Episode 45000, Average Reward Last 1000: -4.50, eps=0.0931
# Episode 45200, Average Reward Last 1000: -4.52, eps=0.0922
# Episode 45400, Average Reward Last 1000: -4.56, eps=0.0912
# Episode 45600, Average Reward Last 1000: -4.35, eps=0.0902
# Episode 45800, Average Reward Last 1000: -4.10, eps=0.0892
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 279185
# good_exp_1                    : 225070
# good_exp                      : 141780
# Episode 46000, Average Reward Last 1000: -4.06, eps=0.0883
# Episode 46200, Average Reward Last 1000: -4.08, eps=0.0871
# Episode 46400, Average Reward Last 1000: -4.00, eps=0.0860
# Episode 46600, Average Reward Last 1000: -4.06, eps=0.0848
# Episode 46800, Average Reward Last 1000: -3.89, eps=0.0837
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 296738
# good_exp_1                    : 229514
# good_exp                      : 144814
# Episode 47000, Average Reward Last 1000: -3.83, eps=0.0826
# Episode 47200, Average Reward Last 1000: -3.70, eps=0.0816
# Episode 47400, Average Reward Last 1000: -3.67, eps=0.0806
# Episode 47600, Average Reward Last 1000: -3.55, eps=0.0797
# Episode 47800, Average Reward Last 1000: -3.57, eps=0.0785
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 314224
# good_exp_1                    : 233933
# good_exp                      : 147797
# Episode 48000, Average Reward Last 1000: -3.60, eps=0.0772
# Plays: 218 in episode 48177
# Episode 48200, Average Reward Last 1000: -3.25, eps=0.0759
# Plays: 213 in episode 48210
# Plays: 204 in episode 48386
# Episode 48400, Average Reward Last 1000: -2.78, eps=0.0747
# Plays: 223 in episode 48421
# Episode 48600, Average Reward Last 1000: -2.55, eps=0.0735
# Plays: 211 in episode 48702
# Episode 48800, Average Reward Last 1000: -2.26, eps=0.0724
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 334848
# good_exp_1                    : 238596
# good_exp                      : 150986
# Episode 49000, Average Reward Last 1000: -1.52, eps=0.0715
# Episode 49200, Average Reward Last 1000: -1.20, eps=0.0706
# Episode 49400, Average Reward Last 1000: -1.01, eps=0.0697
# Episode 49600, Average Reward Last 1000: -0.47, eps=0.0689
# Episode 49800, Average Reward Last 1000: 0.07, eps=0.0682
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 348841
# good_exp_1                    : 243780
# good_exp                      : 154479
# Episode 50000, Average Reward Last 1000: 0.14, eps=0.0674
# Finished run 1/64 → all_rewards.1.grid_00_221419.csv
# Configuration saved to config_1_grid_01_225806.txt
# Episode 200, Average Reward Last 400: -1.42, eps=0.0671
# Episode 400, Average Reward Last 800: -0.80, eps=0.0668
# Episode 600, Average Reward Last 1000: -0.80, eps=0.0666
# Episode 800, Average Reward Last 1000: -0.94, eps=0.0663
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 5340
# too_few_pts                   : 4235
# good_exp                      : 3176
# draw_to_tgt                   : 2085
# Episode 1000, Average Reward Last 1000: -1.04, eps=0.0661
# Episode 1200, Average Reward Last 1000: -0.99, eps=0.0659
# Episode 1400, Average Reward Last 1000: -1.20, eps=0.0656
# Episode 1600, Average Reward Last 1000: -1.33, eps=0.0654
# Episode 1800, Average Reward Last 1000: -1.38, eps=0.0651
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 10636
# too_few_pts                   : 8552
# good_exp                      : 6412
# draw_to_tgt                   : 4046
# Episode 2000, Average Reward Last 1000: -1.49, eps=0.0649
# Episode 2200, Average Reward Last 1000: -1.51, eps=0.0646
# Episode 2400, Average Reward Last 1000: -1.65, eps=0.0643
# Episode 2600, Average Reward Last 1000: -1.50, eps=0.0641
# Episode 2800, Average Reward Last 1000: -1.48, eps=0.0638
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 15970
# too_few_pts                   : 12838
# good_exp                      : 9662
# draw_to_tgt                   : 6500
# Episode 3000, Average Reward Last 1000: -1.27, eps=0.0636
# Episode 3200, Average Reward Last 1000: -1.34, eps=0.0633
# Episode 3400, Average Reward Last 1000: -1.31, eps=0.0630
# Episode 3600, Average Reward Last 1000: -1.54, eps=0.0628
# Episode 3800, Average Reward Last 1000: -1.56, eps=0.0625
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 21277
# too_few_pts                   : 17102
# good_exp                      : 12867
# draw_to_tgt                   : 9145
# Episode 4000, Average Reward Last 1000: -1.64, eps=0.0622
# Episode 4200, Average Reward Last 1000: -1.59, eps=0.0620
# Episode 4400, Average Reward Last 1000: -1.56, eps=0.0617
# Episode 4600, Average Reward Last 1000: -1.46, eps=0.0615
# Episode 4800, Average Reward Last 1000: -1.43, eps=0.0612
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 26637
# too_few_pts                   : 21342
# good_exp                      : 16127
# draw_to_tgt                   : 11747
# Episode 5000, Average Reward Last 1000: -1.47, eps=0.0610
# Episode 5200, Average Reward Last 1000: -1.48, eps=0.0607
# Episode 5400, Average Reward Last 1000: -1.49, eps=0.0605
# Episode 5600, Average Reward Last 1000: -1.58, eps=0.0602
# Episode 5800, Average Reward Last 1000: -1.56, eps=0.0600
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 31855
# too_few_pts                   : 25701
# good_exp                      : 19322
# draw_to_tgt                   : 14566
# Episode 6000, Average Reward Last 1000: -1.56, eps=0.0597
# Episode 6200, Average Reward Last 1000: -1.60, eps=0.0594
# Episode 6400, Average Reward Last 1000: -1.71, eps=0.0592
# Episode 6600, Average Reward Last 1000: -1.71, eps=0.0589
# Episode 6800, Average Reward Last 1000: -1.95, eps=0.0586
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 37072
# too_few_pts                   : 30043
# good_exp                      : 22558
# draw_to_tgt                   : 17764
# Episode 7000, Average Reward Last 1000: -2.19, eps=0.0584
# Episode 7200, Average Reward Last 1000: -2.25, eps=0.0581
# Episode 7400, Average Reward Last 1000: -2.24, eps=0.0578
# Episode 7600, Average Reward Last 1000: -2.48, eps=0.0576
# Episode 7800, Average Reward Last 1000: -2.50, eps=0.0573
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 42198
# too_few_pts                   : 34405
# good_exp                      : 25723
# draw_to_tgt                   : 21195
# Episode 8000, Average Reward Last 1000: -2.45, eps=0.0570
# Episode 8200, Average Reward Last 1000: -2.53, eps=0.0568
# Episode 8400, Average Reward Last 1000: -2.72, eps=0.0565
# Episode 8600, Average Reward Last 1000: -2.73, eps=0.0562
# Episode 8800, Average Reward Last 1000: -2.79, eps=0.0559
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 47287
# too_few_pts                   : 38716
# good_exp                      : 28913
# draw_to_tgt                   : 25286
# Episode 9000, Average Reward Last 1000: -2.86, eps=0.0556
# Episode 9200, Average Reward Last 1000: -2.88, eps=0.0554
# Episode 9400, Average Reward Last 1000: -2.81, eps=0.0551
# Episode 9600, Average Reward Last 1000: -2.73, eps=0.0548
# Episode 9800, Average Reward Last 1000: -2.71, eps=0.0545
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 52434
# too_few_pts                   : 43040
# good_exp                      : 32100
# draw_to_tgt                   : 29430
# Episode 10000, Average Reward Last 1000: -2.52, eps=0.0543
# Episode 10200, Average Reward Last 1000: -2.54, eps=0.0540
# Episode 10400, Average Reward Last 1000: -2.52, eps=0.0537
# Episode 10600, Average Reward Last 1000: -2.61, eps=0.0534
# Episode 10800, Average Reward Last 1000: -2.68, eps=0.0530
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 57369
# too_few_pts                   : 47295
# draw_to_tgt                   : 35239
# good_exp                      : 35236
# Episode 11000, Average Reward Last 1000: -3.10, eps=0.0527
# Episode 11200, Average Reward Last 1000: -3.23, eps=0.0524
# Episode 11400, Average Reward Last 1000: -3.66, eps=0.0520
# Episode 11600, Average Reward Last 1000: -3.71, eps=0.0516
# Episode 11800, Average Reward Last 1000: -3.83, eps=0.0513
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 62098
# too_few_pts                   : 51346
# draw_to_tgt                   : 42698
# good_exp                      : 38314
# Episode 12000, Average Reward Last 1000: -3.63, eps=0.0509
# Episode 12200, Average Reward Last 1000: -3.65, eps=0.0506
# Episode 12400, Average Reward Last 1000: -3.16, eps=0.0503
# Episode 12600, Average Reward Last 1000: -3.10, eps=0.0500
# Episode 12800, Average Reward Last 1000: -2.73, eps=0.0497
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 67153
# too_few_pts                   : 55325
# draw_to_tgt                   : 48769
# good_exp                      : 41573
# Episode 13000, Average Reward Last 1000: -2.53, eps=0.0494
# Episode 13200, Average Reward Last 1000: -2.32, eps=0.0491
# Episode 13400, Average Reward Last 1000: -2.20, eps=0.0488
# Episode 13600, Average Reward Last 1000: -1.91, eps=0.0485
# Episode 13800, Average Reward Last 1000: -1.85, eps=0.0482
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 72365
# too_few_pts                   : 59339
# draw_to_tgt                   : 53786
# good_exp                      : 44879
# Episode 14000, Average Reward Last 1000: -1.77, eps=0.0480
# Episode 14200, Average Reward Last 1000: -1.74, eps=0.0477
# Episode 14400, Average Reward Last 1000: -1.62, eps=0.0474
# Episode 14600, Average Reward Last 1000: -1.51, eps=0.0472
# Episode 14800, Average Reward Last 1000: -1.50, eps=0.0469
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 77653
# too_few_pts                   : 63439
# draw_to_tgt                   : 58412
# good_exp                      : 48223
# Episode 15000, Average Reward Last 1000: -1.44, eps=0.0467
# Episode 15200, Average Reward Last 1000: -1.33, eps=0.0464
# Episode 15400, Average Reward Last 1000: -1.75, eps=0.0461
# Episode 15600, Average Reward Last 1000: -2.21, eps=0.0458
# Episode 15800, Average Reward Last 1000: -2.48, eps=0.0455
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 82623
# too_few_pts                   : 67618
# draw_to_tgt                   : 64494
# good_exp                      : 51386
# Episode 16000, Average Reward Last 1000: -2.67, eps=0.0452
# Episode 16200, Average Reward Last 1000: -2.83, eps=0.0450
# Episode 16400, Average Reward Last 1000: -2.74, eps=0.0447
# Episode 16600, Average Reward Last 1000: -2.50, eps=0.0444
# Episode 16800, Average Reward Last 1000: -2.28, eps=0.0442
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 87758
# too_few_pts                   : 71885
# draw_to_tgt                   : 70264
# good_exp                      : 54612
# Episode 17000, Average Reward Last 1000: -2.22, eps=0.0439
# Episode 17200, Average Reward Last 1000: -2.30, eps=0.0436
# Episode 17400, Average Reward Last 1000: -2.12, eps=0.0434
# Episode 17600, Average Reward Last 1000: -2.06, eps=0.0431
# Episode 17800, Average Reward Last 1000: -2.05, eps=0.0429
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 92915
# too_few_pts                   : 76153
# draw_to_tgt                   : 75529
# good_exp                      : 57882
# Episode 18000, Average Reward Last 1000: -2.10, eps=0.0426
# Episode 18200, Average Reward Last 1000: -1.79, eps=0.0424
# Episode 18400, Average Reward Last 1000: -1.75, eps=0.0422
# Episode 18600, Average Reward Last 1000: -1.72, eps=0.0419
# Episode 18800, Average Reward Last 1000: -1.64, eps=0.0417
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 98285
# too_few_pts                   : 80429
# draw_to_tgt                   : 80405
# good_exp                      : 61213
# Episode 19000, Average Reward Last 1000: -1.57, eps=0.0415
# Episode 19200, Average Reward Last 1000: -1.61, eps=0.0412
# Episode 19400, Average Reward Last 1000: -1.59, eps=0.0410
# Episode 19600, Average Reward Last 1000: -1.57, eps=0.0408
# Episode 19800, Average Reward Last 1000: -1.58, eps=0.0406
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 103643
# draw_to_tgt                   : 85127
# too_few_pts                   : 84721
# good_exp                      : 64550
# Episode 20000, Average Reward Last 1000: -1.62, eps=0.0404
# Episode 20200, Average Reward Last 1000: -1.61, eps=0.0401
# Episode 20400, Average Reward Last 1000: -1.58, eps=0.0399
# Episode 20600, Average Reward Last 1000: -1.55, eps=0.0397
# Episode 20800, Average Reward Last 1000: -1.58, eps=0.0395
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 109046
# draw_to_tgt                   : 90075
# too_few_pts                   : 89022
# good_exp                      : 67977
# Episode 21000, Average Reward Last 1000: -1.56, eps=0.0393
# Episode 21200, Average Reward Last 1000: -1.56, eps=0.0390
# Episode 21400, Average Reward Last 1000: -1.49, eps=0.0388
# Episode 21600, Average Reward Last 1000: -0.94, eps=0.0386
# Episode 21800, Average Reward Last 1000: -0.50, eps=0.0384
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 114586
# draw_to_tgt                   : 94722
# too_few_pts                   : 93131
# good_exp                      : 71393
# Episode 22000, Average Reward Last 1000: -0.08, eps=0.0382
# Episode 22200, Average Reward Last 1000: 0.33, eps=0.0380
# Episode 22400, Average Reward Last 1000: 0.53, eps=0.0378
# Episode 22600, Average Reward Last 1000: 0.28, eps=0.0376
# Episode 22800, Average Reward Last 1000: 0.19, eps=0.0374
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 120139
# draw_to_tgt                   : 98784
# too_few_pts                   : 97239
# good_exp                      : 74824
# Episode 23000, Average Reward Last 1000: 0.11, eps=0.0372
# Episode 23200, Average Reward Last 1000: -0.03, eps=0.0370
# Episode 23400, Average Reward Last 1000: 0.04, eps=0.0369
# Episode 23600, Average Reward Last 1000: -0.03, eps=0.0367
# Episode 23800, Average Reward Last 1000: -0.23, eps=0.0365
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 125655
# draw_to_tgt                   : 101859
# too_few_pts                   : 101445
# good_exp                      : 78232
# Episode 24000, Average Reward Last 1000: -0.35, eps=0.0364
# Episode 24200, Average Reward Last 1000: -0.51, eps=0.0362
# Episode 24400, Average Reward Last 1000: -0.69, eps=0.0360
# Episode 24600, Average Reward Last 1000: -0.98, eps=0.0359
# Episode 24800, Average Reward Last 1000: -1.23, eps=0.0357
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 131019
# too_few_pts                   : 105782
# draw_to_tgt                   : 105417
# good_exp                      : 81529
# Episode 25000, Average Reward Last 1000: -1.51, eps=0.0355
# Episode 25200, Average Reward Last 1000: -1.94, eps=0.0353
# Episode 25400, Average Reward Last 1000: -2.36, eps=0.0352
# Episode 25600, Average Reward Last 1000: -2.62, eps=0.0350
# Episode 25800, Average Reward Last 1000: -2.82, eps=0.0348
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 136247
# draw_to_tgt                   : 110219
# too_few_pts                   : 110207
# good_exp                      : 84802
# Episode 26000, Average Reward Last 1000: -3.23, eps=0.0346
# Episode 26200, Average Reward Last 1000: -3.38, eps=0.0344
# Episode 26400, Average Reward Last 1000: -3.37, eps=0.0342
# Episode 26600, Average Reward Last 1000: -3.18, eps=0.0341
# Episode 26800, Average Reward Last 1000: -2.84, eps=0.0339
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 141539
# draw_to_tgt                   : 114642
# too_few_pts                   : 114540
# good_exp                      : 88140
# Episode 27000, Average Reward Last 1000: -2.37, eps=0.0337
# Episode 27200, Average Reward Last 1000: -2.44, eps=0.0335
# Episode 27400, Average Reward Last 1000: -2.55, eps=0.0333
# Episode 27600, Average Reward Last 1000: -2.80, eps=0.0330
# Episode 27800, Average Reward Last 1000: -3.17, eps=0.0328
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 146446
# draw_to_tgt                   : 122045
# too_few_pts                   : 118726
# good_exp                      : 91239
# Episode 28000, Average Reward Last 1000: -3.49, eps=0.0326
# Episode 28200, Average Reward Last 1000: -3.30, eps=0.0324
# Episode 28400, Average Reward Last 1000: -3.31, eps=0.0321
# Episode 28600, Average Reward Last 1000: -3.37, eps=0.0319
# Episode 28800, Average Reward Last 1000: -3.55, eps=0.0317
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 151652
# draw_to_tgt                   : 129012
# too_few_pts                   : 122962
# good_exp                      : 94571
# Episode 29000, Average Reward Last 1000: -3.04, eps=0.0315
# Episode 29200, Average Reward Last 1000: -2.38, eps=0.0313
# Episode 29400, Average Reward Last 1000: -1.65, eps=0.0311
# Episode 29600, Average Reward Last 1000: -1.02, eps=0.0310
# Episode 29800, Average Reward Last 1000: -0.12, eps=0.0308
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 157342
# draw_to_tgt                   : 133805
# too_few_pts                   : 126821
# good_exp                      : 98207
# Episode 30000, Average Reward Last 1000: 0.08, eps=0.0306
# Episode 30200, Average Reward Last 1000: -0.01, eps=0.0305
# Episode 30400, Average Reward Last 1000: -0.03, eps=0.0303
# Episode 30600, Average Reward Last 1000: -0.08, eps=0.0301
# Episode 30800, Average Reward Last 1000: -0.34, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 162830
# draw_to_tgt                   : 139218
# too_few_pts                   : 130847
# good_exp                      : 101678
# Episode 31000, Average Reward Last 1000: -0.57, eps=0.0300
# Episode 31200, Average Reward Last 1000: -0.67, eps=0.0300
# Episode 31400, Average Reward Last 1000: -0.93, eps=0.0300
# Episode 31600, Average Reward Last 1000: -0.92, eps=0.0300
# Episode 31800, Average Reward Last 1000: -0.91, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 168284
# draw_to_tgt                   : 145899
# too_few_pts                   : 134883
# good_exp                      : 105134
# Episode 32000, Average Reward Last 1000: -0.90, eps=0.0300
# Episode 32200, Average Reward Last 1000: -0.83, eps=0.0300
# Episode 32400, Average Reward Last 1000: -0.64, eps=0.0300
# Episode 32600, Average Reward Last 1000: -0.60, eps=0.0300
# Episode 32800, Average Reward Last 1000: -0.60, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 173816
# draw_to_tgt                   : 150942
# too_few_pts                   : 138923
# good_exp                      : 108620
# Episode 33000, Average Reward Last 1000: -0.30, eps=0.0300
# Episode 33200, Average Reward Last 1000: 0.01, eps=0.0300
# Episode 33400, Average Reward Last 1000: 0.16, eps=0.0300
# Episode 33600, Average Reward Last 1000: 0.33, eps=0.0300
# Episode 33800, Average Reward Last 1000: 0.46, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 179515
# draw_to_tgt                   : 155703
# too_few_pts                   : 142794
# good_exp                      : 112177
# Episode 34000, Average Reward Last 1000: 0.28, eps=0.0300
# Episode 34200, Average Reward Last 1000: 0.01, eps=0.0300
# Episode 34400, Average Reward Last 1000: -0.05, eps=0.0300
# Episode 34600, Average Reward Last 1000: -0.20, eps=0.0300
# Episode 34800, Average Reward Last 1000: -0.17, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 185127
# draw_to_tgt                   : 160770
# too_few_pts                   : 146739
# good_exp                      : 115768
# Episode 35000, Average Reward Last 1000: -0.21, eps=0.0300
# Episode 35200, Average Reward Last 1000: -0.20, eps=0.0300
# Episode 35400, Average Reward Last 1000: -0.92, eps=0.0300
# Episode 35600, Average Reward Last 1000: -1.48, eps=0.0300
# Episode 35800, Average Reward Last 1000: -1.99, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 190177
# draw_to_tgt                   : 171779
# too_few_pts                   : 150695
# good_exp                      : 119068
# Episode 36000, Average Reward Last 1000: -2.30, eps=0.0300
# Episode 36200, Average Reward Last 1000: -2.73, eps=0.0300
# Episode 36400, Average Reward Last 1000: -2.60, eps=0.0300
# Episode 36600, Average Reward Last 1000: -2.43, eps=0.0300
# Episode 36800, Average Reward Last 1000: -1.96, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 195386
# draw_to_tgt                   : 183637
# too_few_pts                   : 154408
# good_exp                      : 122498
# Episode 37000, Average Reward Last 1000: -1.46, eps=0.0300
# Episode 37200, Average Reward Last 1000: -0.80, eps=0.0300
# Episode 37400, Average Reward Last 1000: 0.06, eps=0.0300
# Episode 37600, Average Reward Last 1000: 0.78, eps=0.0300
# Episode 37800, Average Reward Last 1000: 0.98, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 201028
# draw_to_tgt                   : 192462
# too_few_pts                   : 157854
# good_exp                      : 126148
# Episode 38000, Average Reward Last 1000: 1.09, eps=0.0300
# Episode 38200, Average Reward Last 1000: 0.85, eps=0.0300
# Episode 38400, Average Reward Last 1000: 0.71, eps=0.0300
# Episode 38600, Average Reward Last 1000: 0.55, eps=0.0300
# Episode 38800, Average Reward Last 1000: 0.57, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 206787
# draw_to_tgt                   : 199300
# too_few_pts                   : 161456
# good_exp                      : 129870
# Episode 39000, Average Reward Last 1000: 0.41, eps=0.0300
# Episode 39200, Average Reward Last 1000: 0.07, eps=0.0300
# Episode 39400, Average Reward Last 1000: -0.53, eps=0.0300
# Episode 39600, Average Reward Last 1000: -1.07, eps=0.0300
# Plays: 231 in episode 39746
# Episode 39800, Average Reward Last 1000: -1.44, eps=0.0300
# Plays: 215 in episode 39973
# Plays: 234 in episode 39975
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 212061
# good_exp_1                    : 211864
# too_few_pts                   : 165231
# good_exp                      : 133209
# Episode 40000, Average Reward Last 1000: -1.66, eps=0.0300
# Plays: 209 in episode 40193
# Episode 40200, Average Reward Last 1000: -1.74, eps=0.0300
# Episode 40400, Average Reward Last 1000: -1.51, eps=0.0300
# Episode 40600, Average Reward Last 1000: -1.13, eps=0.0300
# Episode 40800, Average Reward Last 1000: -1.02, eps=0.0300
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 229158
# good_exp_1                    : 217016
# too_few_pts                   : 168734
# good_exp                      : 136694
# Episode 41000, Average Reward Last 1000: -1.01, eps=0.0300
# Episode 41200, Average Reward Last 1000: -0.39, eps=0.0300
# Episode 41400, Average Reward Last 1000: 0.21, eps=0.0300
# Episode 41600, Average Reward Last 1000: 0.82, eps=0.0300
# Plays: 202 in episode 41756
# Episode 41800, Average Reward Last 1000: 1.32, eps=0.0300
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 242124
# good_exp_1                    : 222690
# too_few_pts                   : 171850
# good_exp                      : 140441
# Episode 42000, Average Reward Last 1000: 2.02, eps=0.0300
# Episode 42200, Average Reward Last 1000: 2.39, eps=0.0300
# Episode 42400, Average Reward Last 1000: 2.49, eps=0.0300
# Episode 42600, Average Reward Last 1000: 2.41, eps=0.0300
# Episode 42800, Average Reward Last 1000: 2.39, eps=0.0300
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 253787
# good_exp_1                    : 228488
# too_few_pts                   : 175001
# good_exp                      : 144258
# Episode 43000, Average Reward Last 1000: 2.20, eps=0.0300
# Episode 43200, Average Reward Last 1000: 1.92, eps=0.0300
# Episode 43400, Average Reward Last 1000: 1.75, eps=0.0300
# Plays: 203 in episode 43572
# Episode 43600, Average Reward Last 1000: 1.63, eps=0.0300
# Episode 43800, Average Reward Last 1000: 1.78, eps=0.0300
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 265338
# good_exp_1                    : 234148
# too_few_pts                   : 178261
# good_exp                      : 147948
# Episode 44000, Average Reward Last 1000: 1.90, eps=0.0300
# Episode 44200, Average Reward Last 1000: 1.83, eps=0.0300
# Episode 44400, Average Reward Last 1000: 1.73, eps=0.0300
# Episode 44600, Average Reward Last 1000: 1.82, eps=0.0300
# Episode 44800, Average Reward Last 1000: 1.52, eps=0.0300
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 276500
# good_exp_1                    : 239884
# too_few_pts                   : 181568
# good_exp                      : 151691
# Episode 45000, Average Reward Last 1000: 1.17, eps=0.0300
# Episode 45200, Average Reward Last 1000: 1.32, eps=0.0300
# Episode 45400, Average Reward Last 1000: 1.41, eps=0.0300
# Episode 45600, Average Reward Last 1000: 1.17, eps=0.0300
# Episode 45800, Average Reward Last 1000: 1.12, eps=0.0300
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 287625
# good_exp_1                    : 245502
# too_few_pts                   : 185056
# good_exp                      : 155325
# Episode 46000, Average Reward Last 1000: 1.13, eps=0.0300
# Episode 46200, Average Reward Last 1000: 0.79, eps=0.0300
# Episode 46400, Average Reward Last 1000: 0.58, eps=0.0300
# Episode 46600, Average Reward Last 1000: 0.63, eps=0.0300
# Episode 46800, Average Reward Last 1000: 0.63, eps=0.0300
# Plays: 225 in episode 46974
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 295069
# good_exp_1                    : 251119
# too_few_pts                   : 188809
# good_exp                      : 158913
# Episode 47000, Average Reward Last 1000: 0.10, eps=0.0300
# Episode 47200, Average Reward Last 1000: -0.18, eps=0.0300
# Episode 47400, Average Reward Last 1000: -0.99, eps=0.0300
# Episode 47600, Average Reward Last 1000: -1.56, eps=0.0300
# Episode 47800, Average Reward Last 1000: -2.09, eps=0.0300
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 307472
# good_exp_1                    : 256135
# too_few_pts                   : 192685
# good_exp                      : 162234
# Episode 48000, Average Reward Last 1000: -2.19, eps=0.0300
# Episode 48200, Average Reward Last 1000: -2.23, eps=0.0300
# Episode 48400, Average Reward Last 1000: -1.88, eps=0.0300
# Episode 48600, Average Reward Last 1000: -1.99, eps=0.0300
# Episode 48800, Average Reward Last 1000: -2.01, eps=0.0300
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 316764
# good_exp_1                    : 261290
# too_few_pts                   : 196622
# good_exp                      : 165557
# Episode 49000, Average Reward Last 1000: -2.01, eps=0.0300
# Episode 49200, Average Reward Last 1000: -2.29, eps=0.0300
# Episode 49400, Average Reward Last 1000: -2.44, eps=0.0300
# Episode 49600, Average Reward Last 1000: -2.58, eps=0.0300
# Episode 49800, Average Reward Last 1000: -2.85, eps=0.0300
#
# === Step Rule Firing Counts ===
# draw_to_tgt                   : 328050
# good_exp_1                    : 266179
# too_few_pts                   : 200627
# good_exp                      : 168747
# Episode 50000, Average Reward Last 1000: -2.92, eps=0.0300
# Finished run 2/64 → all_rewards.1.grid_01_225806.csv
# Configuration saved to config_1_grid_02_234652.txt
# Episode 200, Average Reward Last 400: 0.50, eps=0.0300
# Episode 400, Average Reward Last 800: 0.25, eps=0.0300
# Episode 600, Average Reward Last 1000: 0.08, eps=0.0300
# Episode 800, Average Reward Last 1000: -0.12, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 5548
# too_few_pts                   : 4053
# good_exp                      : 3359
# good_low_val                  : 2928
# draw_to_tgt                   : 2086
# Episode 1000, Average Reward Last 1000: -0.12, eps=0.0300
# Episode 1200, Average Reward Last 1000: -0.41, eps=0.0300
# Episode 1400, Average Reward Last 1000: -0.59, eps=0.0300
# Episode 1600, Average Reward Last 1000: -0.73, eps=0.0300
# Episode 1800, Average Reward Last 1000: -0.88, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 10968
# too_few_pts                   : 8222
# good_exp                      : 6660
# good_low_val                  : 5780
# draw_to_tgt                   : 4094
# Episode 2000, Average Reward Last 1000: -1.12, eps=0.0300
# Episode 2200, Average Reward Last 1000: -1.13, eps=0.0300
# Episode 2400, Average Reward Last 1000: -1.09, eps=0.0300
# Episode 2600, Average Reward Last 1000: -0.99, eps=0.0300
# Episode 2800, Average Reward Last 1000: -0.84, eps=0.0300
#
# === Step Rule Firing Counts ===
# ...
# Episode 5800, Average Reward Last 1000: 1.28, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 34201
# too_few_pts                   : 23468
# good_exp                      : 19885
# good_low_val                  : 17983
# draw_to_tgt                   : 9110
# Episode 6000, Average Reward Last 1000: 1.25, eps=0.0300
# Episode 6200, Average Reward Last 1000: 1.25, eps=0.0300
# Episode 6400, Average Reward Last 1000: 1.26, eps=0.0300
# Episode 6600, Average Reward Last 1000: 1.28, eps=0.0300
# Episode 6800, Average Reward Last 1000: 1.20, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 39933
# too_few_pts                   : 27405
# good_exp                      : 23215
# good_low_val                  : 20978
# draw_to_tgt                   : 10671
# Episode 7000, Average Reward Last 1000: 1.20, eps=0.0300
# Episode 7200, Average Reward Last 1000: 1.33, eps=0.0300
# Episode 7400, Average Reward Last 1000: 1.26, eps=0.0300
# Episode 7600, Average Reward Last 1000: 1.15, eps=0.0300
# Episode 7800, Average Reward Last 1000: 1.11, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 45661
# too_few_pts                   : 31299
# good_exp                      : 26557
# good_low_val                  : 24009
# draw_to_tgt                   : 12298
# Episode 8000, Average Reward Last 1000: 1.06, eps=0.0300
# Episode 8200, Average Reward Last 1000: 0.88, eps=0.0300
# Episode 8400, Average Reward Last 1000: 0.94, eps=0.0300
# Episode 8600, Average Reward Last 1000: 0.96, eps=0.0300
# Episode 8800, Average Reward Last 1000: 0.99, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 51386
# too_few_pts                   : 35218
# good_exp                      : 29947
# good_low_val                  : 27057
# draw_to_tgt                   : 14099
# Episode 9000, Average Reward Last 1000: 1.00, eps=0.0300
# Episode 9200, Average Reward Last 1000: 1.10, eps=0.0300
# Episode 9400, Average Reward Last 1000: 1.15, eps=0.0300
# Episode 9600, Average Reward Last 1000: 1.12, eps=0.0300
# Episode 9800, Average Reward Last 1000: 1.16, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 57167
# too_few_pts                   : 39112
# good_exp                      : 33400
# good_low_val                  : 30138
# draw_to_tgt                   : 15970
# Episode 10000, Average Reward Last 1000: 1.13, eps=0.0300
# Episode 10200, Average Reward Last 1000: 1.05, eps=0.0300
# Episode 10400, Average Reward Last 1000: 0.98, eps=0.0300
# Episode 10600, Average Reward Last 1000: 0.99, eps=0.0300
# Episode 10800, Average Reward Last 1000: 0.85, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 62940
# too_few_pts                   : 42984
# good_exp                      : 36880
# good_low_val                  : 33232
# draw_to_tgt                   : 18140
# Episode 11000, Average Reward Last 1000: 0.89, eps=0.0300
# Episode 11200, Average Reward Last 1000: 0.98, eps=0.0300
# Episode 11400, Average Reward Last 1000: 0.97, eps=0.0300
# Episode 11600, Average Reward Last 1000: 0.99, eps=0.0300
# Episode 11800, Average Reward Last 1000: 1.02, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 68672
# too_few_pts                   : 46856
# good_exp                      : 40373
# good_low_val                  : 36299
# draw_to_tgt                   : 20517
# Episode 12000, Average Reward Last 1000: 1.10, eps=0.0300
# Episode 12200, Average Reward Last 1000: 1.06, eps=0.0300
# Episode 12400, Average Reward Last 1000: 1.14, eps=0.0300
# Episode 12600, Average Reward Last 1000: 1.02, eps=0.0300
# Episode 12800, Average Reward Last 1000: 1.13, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 74392
# too_few_pts                   : 50822
# good_exp                      : 43768
# good_low_val                  : 39339
# draw_to_tgt                   : 22739
# Episode 13000, Average Reward Last 1000: 1.09, eps=0.0300
# Episode 13200, Average Reward Last 1000: 1.01, eps=0.0300
# Episode 13400, Average Reward Last 1000: 0.88, eps=0.0300
# Episode 13600, Average Reward Last 1000: 0.99, eps=0.0300
# Episode 13800, Average Reward Last 1000: 0.92, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 80072
# too_few_pts                   : 54789
# good_exp                      : 47175
# good_low_val                  : 42294
# draw_to_tgt                   : 25209
# Episode 14000, Average Reward Last 1000: 0.91, eps=0.0300
# Episode 14200, Average Reward Last 1000: 0.89, eps=0.0300
# Episode 14400, Average Reward Last 1000: 0.92, eps=0.0300
# Episode 14600, Average Reward Last 1000: 0.88, eps=0.0300
# Episode 14800, Average Reward Last 1000: 0.85, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 85768
# too_few_pts                   : 58782
# good_exp                      : 50642
# good_low_val                  : 45283
# draw_to_tgt                   : 27439
# Episode 15000, Average Reward Last 1000: 0.78, eps=0.0300
# Episode 15200, Average Reward Last 1000: 0.93, eps=0.0300
# Episode 15400, Average Reward Last 1000: 0.86, eps=0.0300
# Episode 15600, Average Reward Last 1000: 0.86, eps=0.0300
# Episode 15800, Average Reward Last 1000: 0.93, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 91424
# too_few_pts                   : 62786
# good_exp                      : 53944
# good_low_val                  : 48262
# draw_to_tgt                   : 29606
# Episode 16000, Average Reward Last 1000: 0.99, eps=0.0300
# Episode 16200, Average Reward Last 1000: 0.90, eps=0.0300
# Episode 16400, Average Reward Last 1000: 1.00, eps=0.0300
# Episode 16600, Average Reward Last 1000: 0.93, eps=0.0300
# Episode 16800, Average Reward Last 1000: 0.87, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 97152
# too_few_pts                   : 66801
# good_exp                      : 57338
# good_low_val                  : 51268
# draw_to_tgt                   : 31862
# Episode 17000, Average Reward Last 1000: 0.78, eps=0.0300
# Episode 17200, Average Reward Last 1000: 0.77, eps=0.0300
# Episode 17400, Average Reward Last 1000: 0.84, eps=0.0300
# Episode 17600, Average Reward Last 1000: 0.97, eps=0.0300
# Episode 17800, Average Reward Last 1000: 1.00, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 102980
# too_few_pts                   : 70705
# good_exp                      : 60883
# good_low_val                  : 54352
# draw_to_tgt                   : 34146
# Episode 18000, Average Reward Last 1000: 1.03, eps=0.0300
# Episode 18200, Average Reward Last 1000: 0.96, eps=0.0300
# Episode 18400, Average Reward Last 1000: 0.75, eps=0.0300
# Episode 18600, Average Reward Last 1000: 0.50, eps=0.0300
# Episode 18800, Average Reward Last 1000: 0.51, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 108754
# too_few_pts                   : 74635
# good_exp                      : 64411
# good_low_val                  : 57365
# draw_to_tgt                   : 37547
# Episode 19000, Average Reward Last 1000: 0.56, eps=0.0300
# Episode 19200, Average Reward Last 1000: 0.52, eps=0.0300
# Episode 19400, Average Reward Last 1000: 0.49, eps=0.0300
# Episode 19600, Average Reward Last 1000: 0.45, eps=0.0300
# Episode 19800, Average Reward Last 1000: 0.38, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 114363
# too_few_pts                   : 78679
# good_exp                      : 67769
# good_low_val                  : 60309
# draw_to_tgt                   : 40303
# Episode 20000, Average Reward Last 1000: 0.32, eps=0.0300
# Episode 20200, Average Reward Last 1000: 0.46, eps=0.0300
# Episode 20400, Average Reward Last 1000: 0.67, eps=0.0300
# Episode 20600, Average Reward Last 1000: 0.86, eps=0.0300
# Episode 20800, Average Reward Last 1000: 0.87, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 120046
# too_few_pts                   : 82650
# good_exp                      : 71212
# good_low_val                  : 63273
# draw_to_tgt                   : 42696
# Episode 21000, Average Reward Last 1000: 0.69, eps=0.0300
# Episode 21200, Average Reward Last 1000: 0.49, eps=0.0300
# Episode 21400, Average Reward Last 1000: 0.24, eps=0.0300
# Episode 21600, Average Reward Last 1000: 0.04, eps=0.0300
# Episode 21800, Average Reward Last 1000: -0.44, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 125614
# too_few_pts                   : 86596
# good_exp                      : 74787
# good_low_val                  : 66310
# draw_to_tgt                   : 48552
# Episode 22000, Average Reward Last 1000: -0.69, eps=0.0300
# Episode 22200, Average Reward Last 1000: -1.12, eps=0.0300
# Episode 22400, Average Reward Last 1000: -1.35, eps=0.0300
# Episode 22600, Average Reward Last 1000: -1.62, eps=0.0300
# Episode 22800, Average Reward Last 1000: -1.62, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 131013
# too_few_pts                   : 90608
# good_exp                      : 78301
# good_low_val                  : 69258
# draw_to_tgt                   : 55468
# Episode 23000, Average Reward Last 1000: -1.65, eps=0.0300
# Episode 23200, Average Reward Last 1000: -1.64, eps=0.0300
# Episode 23400, Average Reward Last 1000: -1.63, eps=0.0300
# Episode 23600, Average Reward Last 1000: -1.32, eps=0.0300
# Episode 23800, Average Reward Last 1000: -1.01, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 136676
# too_few_pts                   : 94469
# good_exp                      : 81924
# good_low_val                  : 72383
# draw_to_tgt                   : 60112
# Episode 24000, Average Reward Last 1000: -0.56, eps=0.0300
# Episode 24200, Average Reward Last 1000: -0.07, eps=0.0300
# Episode 24400, Average Reward Last 1000: 0.22, eps=0.0300
# Episode 24600, Average Reward Last 1000: 0.29, eps=0.0300
# Episode 24800, Average Reward Last 1000: 0.30, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 142359
# too_few_pts                   : 98383
# good_exp                      : 85464
# good_low_val                  : 75485
# draw_to_tgt                   : 63786
# Episode 25000, Average Reward Last 1000: 0.17, eps=0.0300
# Episode 25200, Average Reward Last 1000: 0.05, eps=0.0300
# Episode 25400, Average Reward Last 1000: 0.01, eps=0.0300
# Episode 25600, Average Reward Last 1000: 0.06, eps=0.0300
# Episode 25800, Average Reward Last 1000: 0.09, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 147960
# too_few_pts                   : 102459
# good_exp                      : 88867
# good_low_val                  : 78398
# draw_to_tgt                   : 66951
# Episode 26000, Average Reward Last 1000: 0.09, eps=0.0300
# Episode 26200, Average Reward Last 1000: 0.12, eps=0.0300
# Episode 26400, Average Reward Last 1000: 0.13, eps=0.0300
# Episode 26600, Average Reward Last 1000: 0.01, eps=0.0300
# Episode 26800, Average Reward Last 1000: 0.06, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 153622
# too_few_pts                   : 106459
# good_exp                      : 92361
# good_low_val                  : 81391
# draw_to_tgt                   : 70235
# Episode 27000, Average Reward Last 1000: 0.02, eps=0.0300
# Episode 27200, Average Reward Last 1000: 0.23, eps=0.0300
# Episode 27400, Average Reward Last 1000: 0.33, eps=0.0300
# Episode 27600, Average Reward Last 1000: 0.42, eps=0.0300
# Episode 27800, Average Reward Last 1000: 0.41, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 159292
# too_few_pts                   : 110429
# good_exp                      : 95823
# good_low_val                  : 84383
# draw_to_tgt                   : 73356
# Episode 28000, Average Reward Last 1000: 0.46, eps=0.0300
# Episode 28200, Average Reward Last 1000: -0.32, eps=0.0300
# Episode 28400, Average Reward Last 1000: -1.00, eps=0.0300
# Episode 28600, Average Reward Last 1000: -1.52, eps=0.0300
# Episode 28800, Average Reward Last 1000: -2.15, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 164578
# too_few_pts                   : 114558
# good_exp                      : 99293
# good_low_val                  : 87233
# draw_to_tgt                   : 80206
# Episode 29000, Average Reward Last 1000: -2.34, eps=0.0300
# Episode 29200, Average Reward Last 1000: -1.53, eps=0.0300
# Episode 29400, Average Reward Last 1000: -0.95, eps=0.0300
# Episode 29600, Average Reward Last 1000: -0.36, eps=0.0300
# Episode 29800, Average Reward Last 1000: 0.32, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 170137
# too_few_pts                   : 118657
# good_exp                      : 102559
# good_low_val                  : 90089
# draw_to_tgt                   : 82477
# Episode 30000, Average Reward Last 1000: 0.39, eps=0.0300
# Episode 30200, Average Reward Last 1000: 0.14, eps=0.0300
# Episode 30400, Average Reward Last 1000: -0.32, eps=0.0300
# Episode 30600, Average Reward Last 1000: -0.96, eps=0.0300
# Episode 30800, Average Reward Last 1000: -1.62, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 175354
# too_few_pts                   : 122875
# good_exp                      : 105878
# good_low_val                  : 92762
# draw_to_tgt                   : 88282
# Episode 31000, Average Reward Last 1000: -2.10, eps=0.0300
# Episode 31200, Average Reward Last 1000: -2.47, eps=0.0300
# Episode 31400, Average Reward Last 1000: -2.47, eps=0.0300
# Episode 31600, Average Reward Last 1000: -2.54, eps=0.0300
# Episode 31800, Average Reward Last 1000: -2.54, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 180586
# too_few_pts                   : 127111
# good_exp                      : 109234
# draw_to_tgt                   : 95459
# good_low_val                  : 95422
# Episode 32000, Average Reward Last 1000: -2.34, eps=0.0300
# Episode 32200, Average Reward Last 1000: -1.72, eps=0.0300
# Episode 32400, Average Reward Last 1000: -1.10, eps=0.0300
# Episode 32600, Average Reward Last 1000: -0.33, eps=0.0300
# Episode 32800, Average Reward Last 1000: 0.47, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 186138
# too_few_pts                   : 130983
# good_exp                      : 112624
# draw_to_tgt                   : 101139
# good_low_val                  : 98235
# Episode 33000, Average Reward Last 1000: 0.99, eps=0.0300
# Episode 33200, Average Reward Last 1000: 0.99, eps=0.0300
# Episode 33400, Average Reward Last 1000: 0.95, eps=0.0300
# Episode 33600, Average Reward Last 1000: 1.01, eps=0.0300
# Episode 33800, Average Reward Last 1000: 0.93, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 191746
# too_few_pts                   : 134834
# good_exp                      : 116169
# draw_to_tgt                   : 107075
# good_low_val                  : 101143
# Episode 34000, Average Reward Last 1000: 0.95, eps=0.0300
# Episode 34200, Average Reward Last 1000: 0.93, eps=0.0300
# Episode 34400, Average Reward Last 1000: 0.82, eps=0.0300
# Episode 34600, Average Reward Last 1000: 0.68, eps=0.0300
# Episode 34800, Average Reward Last 1000: 0.64, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 197331
# too_few_pts                   : 138898
# good_exp                      : 119558
# draw_to_tgt                   : 110410
# good_low_val                  : 103965
# Episode 35000, Average Reward Last 1000: 0.60, eps=0.0300
# Episode 35200, Average Reward Last 1000: 0.54, eps=0.0300
# Episode 35400, Average Reward Last 1000: 0.54, eps=0.0300
# Episode 35600, Average Reward Last 1000: 0.65, eps=0.0300
# Episode 35800, Average Reward Last 1000: 0.60, eps=0.0300
#
# === Step Rule Firing Counts ===
# good_exp_1                    : 203001
# too_few_pts                   : 142947
# good_exp                      : 122934
# draw_to_tgt                   : 112965
# good_low_val                  : 106863
# Episode 36000, Average Reward Last 1000: 0.56, eps=0.0300
# Episode 36200, Average Reward Last 1000: 0.56, eps=0.0300
# Episode 36400, Average Reward Last 1000: 0.65, eps=0.0300
# Episode 36600, Average Reward Last 1000: 0.62, eps=0.0300

# %%
# torch.save(model.state_dict(), 'lc_model_'+fv+'.pt')

# %%
# model.load_state_dict(torch.load('lc_model_v1B_2.pt'))
# model.eval()  # Important: sets model to evaluation mode (no dropout etc.)
# Out:
# ActorCritic(
#   (fc1): Linear(in_features=43, out_features=96, bias=True)
#   (fc2): Linear(in_features=96, out_features=32, bias=True)
#   (dropout): Dropout(p=0.15, inplace=False)
#   (policy_action_head): Linear(in_features=32, out_features=18, bias=True)
#   (policy_draw_head): Linear(in_features=32, out_features=4, bias=True)
#   (value_head): Linear(in_features=32, out_features=1, bias=True)
# )
